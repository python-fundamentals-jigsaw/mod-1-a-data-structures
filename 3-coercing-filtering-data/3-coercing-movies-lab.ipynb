# %% [markdown]
# # Coercing and Reducing Data Lab

# %% [markdown]
# ### Introduction

# %% [markdown]
# In this lesson, we'll see how we can use loops and list comprehensions to both reduce the amount of information, and coerce our data.

# %% [markdown]
# ### Loading the Data

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/jigsawlabs-student/mod-1-a-data-structures/master/3-coercing-filtering-data/imdb_movies.csv')
movies = df.to_dict('records')

# %%
movies[:2]
# Out:
# [{'title': 'Avatar',
#   'genre': 'Action',
#   'budget': 237000000,
#   'runtime': 162.0,
#   'year': 2009,
#   'month': 12,
#   'revenue': 2787965087},
#  {'title': "Pirates of the Caribbean: At World's End",
#   'genre': 'Adventure',
#   'budget': 300000000,
#   'runtime': 169.0,
#   'year': 2007,
#   'month': 5,
#   'revenue': 961000000}]

# %% [markdown]
# ### Exploring Data

# %% [markdown]
# 1. Start by selecting the first movie from the list of movies, this way we can get a sense of our data.

# %%
first_movie = movies[0]
first_movie
# {'title': 'Avatar',
#  'genre': 'Action',
#  'budget': 237000000,
#  'runtime': 162.0,
#  'year': 2009,
#  'month': 12,
#  'revenue': 2787965087}
# Out:
# {'title': 'Avatar',
#  'genre': 'Action',
#  'budget': 237000000,
#  'runtime': 162.0,
#  'year': 2009,
#  'month': 12,
#  'revenue': 2787965087}

# %% [markdown]
# Now let's just return the keys from the dictionary..

# %%
movie_keys = None
movie_keys

# dict_keys(['title', 'genre', 'budget', 'runtime', 'year', 'month', 'revenue'])

# %% [markdown]
# And turn it into a list to calculate the number of keys.

# %%
num_keys = None
# 7

# %% [markdown]
# 2. Now let's see how many movies we have

# %%
movies_count = None
movies_count
# 2000

# %% [markdown]
# ### 2. Using Loops to Reduce Data

# %% [markdown]
# Now we would like to plot the amount of money that each movie makes along with it's name.
#
# To do so, loop through the list to select only `title` from each movie.
# > Let's practice this using first a `for` loop, and then list comprehension.

# %% [markdown]
# 1. Use a `for` loop and the `append` method to add each title to a list.

# %%
titles = None

# %% [markdown]
# 2. Now do the same thing using list comprehension.

# %%
titles = None

# %%
# titles[:3]
# ['Avatar', 
# "Pirates of the Caribbean: At World's End", 
# 'Spectre']

# %% [markdown]
# 3. Select the revenue from each movie using list comprehension

# %%
revenues = []

# %%
revenues[:3]
# [2787965087, 961000000, 880674609]
# Out:
# []

# %% [markdown]
# 4. Now select the year from each movie.

# %%
years = None

# %% [markdown]
# > Press `shift + return` on the cell below to plot the movie information.

# %%
import plotly.graph_objects as go
scatter = go.Scatter(x = years,
                     y = revenues, 
                     hovertext=titles, 
                     mode = 'markers')
fig = go.Figure(scatter)
fig

# %% [markdown]
# ## 3. Coercing Data

# %% [markdown]
# From here, we can see we only have movies from a certain number of years.  We can see the unique list of years with the by turning our list into a `set`.

# %%
years = [movie['year'] for movie in movies]
years[:2]
# [2009, 2007]
# Out:
# []

# %% [markdown]
# Turn this into a unique set of years.

# %%
unique_years = None

# %%
len(unique_years)
# 48
# Out:
# 48

# %% [markdown]
# But if we want to explore certain years, we cannot slice elements from a set.

# %%
unique_years[:2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-c4b84aada228> in <module>
# ----> 1 unique_years[:2]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# So let's change this set back to a list.

# %%
unique_years = list(set(years))

# %%
unique_years[:2]
# [1940, 1962]
# Out:
# [1940, 1962]

# %% [markdown]
# 1. Now find unique list of genres in our collection of movies above.

# %%
unique_genres = None

# %%
len(unique_genres)
# 12

# %%
unique_genres[:5]
# [nan, 'Science Fiction', 'Action', 'Romance', 'Horror']
# Out:
# [nan, 'Science Fiction', 'Action', 'Romance', 'Horror']

# %% [markdown]
# 2. Calculate the net revenue for each movie
# * net revenue = revenue - budget

# %%
net_revenues = None

# %%
net_revenues[:5]
# [2550965087, 661000000, 635674609, 834939099, 24139100]
# Out:
# [2550965087, 661000000, 635674609, 834939099, 24139100]

# %% [markdown]
# Now it would be great to plot the net revenue along with the genre.  To do so we need to replace each occurrence of a movie genre with a corresponding color.  For example, if we look at the first genre of each of the first five movies:

# %%
genres[:5]
# ['Action', 'Adventure', 'Action', 'Action', 'Action']
# Out:
# ['Action', 'Adventure', 'Action', 'Action', 'Action']

# %% [markdown]
# We could replace the first five elements below with:

# %% [markdown]
# `['Red', 'Blue', 'Red', 'Red', 'Red']`.

# %% [markdown]
# Here is a dictionary for replacing each of the values to a corresponding color.

# %%
unique_genres
# Out:
# [nan,
#  'Science Fiction',
#  'Action',
#  'Romance',
#  'Horror',
#  'Adventure',
#  'Fantasy',
#  'Thriller',
#  'Comedy',
#  'Drama',
#  'Crime',
#  'Animation']

# %%
colors = ['black', 'yellow', 'yellow', 'red',
          'purple', 'gold', 'gold', 'yellow', 
          'orange', 'green', 'yellow', 'blue']
color_map = dict(zip(unique_genres, colors))

# %%
colors = [color_map[genre] for genre in genres]

# %%
import plotly.graph_objects as go
scatter = go.Scatter(x = years,
                     y = net_revenues, 
                     hovertext=titles, 
                    marker = dict(size=8, color=colors),
                     mode = 'markers')
fig = go.Figure(scatter)
fig

# %% [markdown]
# > No one said it was gonna be pretty.

# %% [markdown]
# 3. Create datetime year and month for each movie

# %% [markdown]
# Now if we look at our data above, we can combine the month and year data into a datetime value.

# %% [markdown]
# Here's how we can create a datetime value.

# %%
import datetime
date = datetime.datetime(2020, 1, 1)
date
# Out:
# datetime.datetime(2020, 1, 1, 0, 0)

# %% [markdown]
# > We must provide a year a month and a day.

# %% [markdown]
# From let's use the month and year attributes to create a new datetime object for every movie.  Use the year and month values provided from each movie, and set the day to `1`.

# %%
first_movie.keys()
# Out:
# dict_keys(['title', 'genre', 'budget', 'runtime', 'year', 'month', 'revenue'])

# %%
dates = None

# %%
dates[:2]
# [datetime.datetime(2009, 12, 1, 0, 0),
# datetime.datetime(2007, 5, 1, 0, 0)]
# Out:
# [datetime.datetime(2009, 12, 1, 0, 0), datetime.datetime(2007, 5, 1, 0, 0)]

# %% [markdown]
# 5. Calculate number of months since now for each movie
# > [Googling is ok](https://stackoverflow.com/questions/4039879/best-way-to-find-the-months-between-two-dates)

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2020, 1, 29, 18, 44, 53, 217329)

# %% [markdown]
# ### Creating new dictionaries

# %% [markdown]
# Now let's create new dictionaries of movie titles, revenues and dates.  Pair together the lists of `titles`, `net_revenues` and `dates`.  The paired data should be a list where each element contains this data for each movie.

# %%
paired_data = []

# %%
paired_data[:3]
# [('Avatar', 2550965087, datetime.datetime(2009, 12, 1, 0, 0)),
#  ("Pirates of the Caribbean: At World's End",
#   661000000,
#   datetime.datetime(2007, 5, 1, 0, 0)),
#  ('Spectre', 635674609, datetime.datetime(2015, 10, 1, 0, 0))]
# Out:
# []

# %% [markdown]
# Now from here, create a list of dictionaries, where there is a new dictionary for every movie.  The keys are defined below.

# %%
keys = ['title', 'net_revenue', 'date']

# %% [markdown]
# Use the paired data above to create the new dictionaries.

# %%
new_movies = []

# %%
new_movies[:2]
# [{'title': 'Avatar',
#   'net_revenue': 2550965087,
#   'date': datetime.datetime(2009, 12, 1, 0, 0)},
#  {'title': "Pirates of the Caribbean: At World's End",
#   'net_revenue': 661000000,
#   'date': datetime.datetime(2007, 5, 1, 0, 0)}]
# Out:
# []
